# %% [markdown]
# <a href="https://colab.research.google.com/github/WaWa-0741/colab_projects/blob/main/HW0523_Wallace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download("popular")
nltk.download("all-corpora")
nltk.download("punkt")
#每次都是要下載
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
#允許讀你的google 硬碟
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls '/content/drive/MyDrive/Colab'
#條列你的文本
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 'Argument Essay outline _ first draft _ We should wash our clothes less often_Zozo.txt'
# 'Argument final drat_Wallace_511061133_20240520.txt'
# 'Argument First Draft_Ruby.txt'
# 'Cancel culture _Wallace_511061133_20240311_V2.txt'
# 'Cause and Effect final drift_Wallace_511061133_V1.txt'
# 'Comparison and  Contrast Final Draft_Wallace_511061133_20240422_V1.txt'
# 'Definition final draft_Wallace_511061133.txt'

# %%
import nltk

from nltk.corpus import PlaintextCorpusReader

corpus_root = '/content/drive/MyDrive/Colab' # 文本的路徑 File Path
wordlists = PlaintextCorpusReader(corpus_root, '.*') # .* => find all files, .txt => 只能讀txt檔

books = wordlists.fileids()# wordlists可改為自己想要的名稱， 類似abc
print(books)
# Out:
# ['Argument Essay outline _ first draft _ We should wash our clothes less often_Zozo.txt', 'Argument First Draft_Ruby.txt', 'Argument final drat_Wallace_511061133_20240520.txt', 'Cancel culture _Wallace_511061133_20240311_V2.txt', 'Cause and Effect final drift_Wallace_511061133_V1.txt', 'Comparison and  Contrast Final Draft_Wallace_511061133_20240422_V1.txt', 'Definition final draft_Wallace_511061133.txt']

# %%
import nltk
testText = wordlists.words('Argument final drat_Wallace_511061133_20240520.txt')
single = nltk.text.Text(testText)
print(single)

#UTF8格式有沒有error， 可從這裡去看
# Out:
# <Text: Wallace Chang Shelly Hsiao Composition May . 20...>

# %%
# 文章中字詞出現次數
single.count("the")# the

# 搜尋字詞功能
single.concordance("the", lines=50)


#找出高頻率單字
import pandas as pd
import numpy as np
import nltk
import os
import nltk.corpus

text = "Argument final drat_Wallace_511061133_20240520.txt"
from nltk.tokenize import word_tokenize
token = word_tokenize(text)

from nltk.probability import FreqDist
fdist = FreqDist(token)
#出現頻率最高的10個單字
fdist1 = fdist.most_common(10)
fdist1
# Out:
# Displaying 45 of 45 matches:
# nation should exit 1 . Introduction : The purpose and the progress of examinati
# it 1 . Introduction : The purpose and the progress of examination 2 . Main Body
#  examination 2 . Main Body A : Adding the pressure to students . 3 . Main Body
# There are no standard answers most of the times . 4 . Main Body C : Limited the
# the times . 4 . Main Body C : Limited the imagination of students . 5 . Conclus
# amination should be changed to follow the trend and upgraded by Technology . Pa
# xit “ Exams have an important role in the process of learning and in the whole
# ole in the process of learning and in the whole educational institution .” Exam
#  tests are a great way to assess what the students have learned with regards to
# morized through exams . In addition , the teachers could be able to understand
# more attention in class when teaching the particular subject . In Taiwan , mock
# ...

# %%
import nltk
testText2 = wordlists.words('Cancel culture _Wallace_511061133_20240311_V2.txt')
abc = nltk.text.Text(testText2)
print(abc)
# Out:
# <Text: Wallace Chang Miss Hsiao Composition Mar . 11...>

# %%
# 關聯字
abc.similar("the")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-6b18ef08867e> in <cell line: 2>()
#       1 # 關聯字
# ----> 2 abc.similar("the")
#
# NameError: name 'abc' is not defined

# %%
#list
context = ["Cancel","Culture","is"]

abc.common_contexts(context)
# Out:
# No common contexts were found

# %%
text123 = wordlists.words('Cause and Effect final drift_Wallace_511061133_V1.txt')
print(text123)
print(len(text123))
# Out:
# ['Wallace', 'Chang', 'Shelly', 'Hsiao', 'Composition', ...]
# 760

# %%
from nltk.tokenize import word_tokenize
whatpeople = wordlists.raw('Cause and Effect final drift_Wallace_511061133_V1.txt')
print(word_tokenize(whatpeople))
print(len(word_tokenize(whatpeople)))

# 將文本進行分詞
tokens = word_tokenize(whatpeople)

# 計算單詞的頻率分佈
fdist = FreqDist(tokens)

# 出現頻率最高的10個單詞
fdist1 = fdist.most_common(10)
print(fdist1)

print('---分隔線---')
# 出現頻率最高的20個單詞
fdist1 = fdist.most_common(20)
print(fdist1)
# Out:
# ['Wallace', 'Chang', 'Shelly', 'Hsiao', 'Composition', 'Apr', '.', '8', ',', '2024', 'Cause', 'and', 'Effect', 'Final', 'Draft', 'Advantage', 'of', 'Keeping', 'English', 'Well', '1', '.', 'Introduction', ':', 'English', 'is', 'the', 'language', 'which', 'most', 'people', 'use', 'around', 'the', 'world', '.', 'The', 'advantages', 'of', 'keeping', 'your', 'English', 'well', 'were', 'divided', 'to', 'three', 'segments', ':', 'personal', 'filed', ',', 'social', 'connection', ',', 'and', 'future', 'development', '.', '2', '.', 'Main', 'body', 'A', ':', 'Personal', 'field', 'a', '.', 'Increase', 'culture', 'content', '.', 'b', '.', 'Enrich', 'inner', 'content', 'of', 'mental', '.', 'c.', 'Multiple', 'learning', 'resources', '.', '3', '.', 'Main', 'body', 'B', ':', 'Social', 'connection', 'a', '.', 'Cross', 'culture', 'communication', 'b', '.', 'Easy', 'to', 'travel', 'abroad', 'c.', 'Engage', 'with', 'friends', '4', '.', 'Main', 'body', 'C', ':', 'Future', 'development', 'a', '.', 'Languag
# ...

# %%
from nltk.tokenize import sent_tokenize
data123 = wordlists.raw('Comparison and  Contrast Final Draft_Wallace_511061133_20240422_V1.txt')
print(sent_tokenize(data123))
print(len(sent_tokenize(data123)))
# Out:
# ['Wallace Chang\r\nShelly Hsiao\r\nComposition \r\nApr.', '22, 2024\r\nComparison & Contrast Final Draft\r\n    The difference between distilled liquor and brewed liquor\r\n1.', 'Introduction: The wines suitable for each occasion are different.', 'Before buying or giving as gifts, you might as well understand the basic classification of wines.', 'What is the difference between distilled liquor and brewed liquor?', 'The difference can be distinguished from the manufacturing process, feeling of taste and application scenarios.', '2.', 'Main body A: Manufacturing process\r\n3.', 'Main body B: Feeling of taste \r\n4.', 'Main body C: Application scenarios\r\n5.', 'Conclusion: Understanding the differences between brewed liquor and distilled liquor could carry you not only adding cultural sense, but also not be rude as giving present.', 'That could help you to choose a liquor that suits you or your friends.', 'The difference between distilled liquor and brewed liquor\r\n    Taiwanese peopl
# ...

# %%
text = wordlists.words('Comparison and  Contrast Final Draft_Wallace_511061133_20240422_V1.txt')
# 相異字詞
set(text)

# 相異字詞排序
tempText = sorted(set(text))
print(tempText)

# 定義詞彙多樣性的函數
def difference(text):
    result = len(set(text)) / len(text)
    return result

print(difference(text))
# Out:
# ['"', '%,', '&', "'", ',', '-', '.', '1', '12', '2', '20', '2024', '22', '3', '30', '4', '40', '5', '78', ':', ';', '?', '@', 'A', 'Application', 'Apr', 'B', 'Because', 'Before', 'Besides', 'Brandy', 'Brewed', 'By', 'C', 'Celsius', 'Chang', 'Comparison', 'Composition', 'Conclusion', 'Contrast', 'Draft', 'Feeling', 'Final', 'For', 'Fruit', 'Generally', 'Hsiao', 'In', 'Introduction', 'It', 'Knowing', 'Main', 'Manufacturing', 'Of', 'On', 'Shelly', 'Taiwanese', 'That', 'The', 'They', 'Understanding', 'Wallace', 'What', 'When', 'You', 'a', 'above', 'add', 'adding', 'addition', 'alcohol', 'all', 'also', 'always', 'ambience', 'an', 'and', 'appeal', 'application', 'appropriate', 'are', 'aroma', 'around', 'as', 'at', 'based', 'basic', 'be', 'been', 'below', 'between', 'beverage', 'body', 'boils', 'brewed', 'brings', 'budget', 'business', 'but', 'buying', 'by', 'can', 'cane', 'carefully', 'carry', 'celebratory', 'cereals', 'choose', 'classification', 'coconuts', 'completely', 'concentration', 
# ...

# %%
# 移除停用詞

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download stopwords if necessary
nltk.download('stopwords')
nltk.download('punkt')


# Read the text file content
whatpeople = wordlists.raw('Cause and Effect final drift_Wallace_511061133_V1.txt')


# 將文本進行分詞
tokens = word_tokenize(whatpeople)


# Initialize the clean_tokens list
clean_tokens = []

# Remove stopwords from the tokens(助教的寫法不會動)
#for token in tokens:
 # if token.lower() in stopwords.words('english'):
 #   clean_tokens.remove(token)

#ChatGPT寫法
stop_words = set(stopwords.words('english'))
clean_tokens = [token for token in tokens if token.lower() not in stop_words]

print(clean_tokens)

freq = nltk.FreqDist(clean_tokens)

# Print frequency items
print(freq.items())

# for key,val in freq.items():
# print (str(key) + ':' + str(val))
freq.plot(20,cumulative=False)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
#助教沒教的功能

# Import matplotlib.pyplot
import matplotlib.pyplot as plt

# Define key_list and value_list
key_list = []
value_list = []
from nltk.probability import FreqDist
fdist = FreqDist(token)
#出現頻率最高的10個單字
fdist1 = fdist.most_common(10)


# Extract data from fdist1
for key,val in fdist1:
  key_list.append(key)
  value_list.append(val)

x=np.arange(len(key_list))            #產生X軸座標序列
plt.bar(x, value_list, tick_label=key_list)  #繪製長條圖
plt.title('Top 10 words')           #設定圖形標題
plt.xlabel('Words')               #設定X軸標籤
plt.ylabel('Nums')               #設定Y軸標籤
plt.show()

# %%
#去除字尾Stemming
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

print(stemmer.stem('harding'))
# Out:
# hard

# %%
import nltk
testText = wordlists.words('Comparison and  Contrast Final Draft_Wallace_511061133_20240422_V1.txt')
single = nltk.text.Text(testText)

findList = ["when","the", "a", "different", "liquor","and"]
single.dispersion_plot(findList)

# %%
# 使用 ConditionalFreqDist()
# 在多個文本中計算特定字詞個數

books = wordlists.fileids()

cfd = nltk.ConditionalFreqDist((fileid, word)
    for fileid in books
    for word in wordlists.words(fileid)
    )

findList = ['can', 'could', 'may', 'might', 'must', 'will', 'shall', 'should','and']
cfd.tabulate(conditions=books, samples=findList)

print("---分隔線---")

books = wordlists.fileids()
print(books)
# Out:
#                                                                           can  could    may  might   must   will  shall should    and
#                     Argument final drat_Wallace_511061133_20240520.txt      1      4      0      0      0      4      0      4     16
#                      Cancel culture _Wallace_511061133_20240311_V2.txt      2      9      0      0      0      2      0      3     24
#                  Cause and Effect final drift_Wallace_511061133_V1.txt      7      6      0      0      0      0      0      0     31
# Comparison and  Contrast Final Draft_Wallace_511061133_20240422_V1.txt      7      6      1      1      0      2      0      1     24
#                           Definition final draft_Wallace_511061133.txt      1      2      0      0      0      0      0      0     22
# ---分隔線---
# ...

# %%
cfd = nltk.ConditionalFreqDist(
    (target, fileid[:7]) # [:7]取至前七位字元
    for fileid in wordlists.fileids() # 取出各個文檔
    for w in wordlists.words(fileid)  # 所有文本的字詞
    for target in ['culture', 'and', 'the'] # 篩選字詞
    if w.lower() == target) # w.lower().startswith(target)  # 字詞+er也能納入計算
cfd.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {'how', 'any', 'otherwise', 'ought', "we've", "won't", 'they', 'have', "why's", 'while', 'or', 'did', 'in', 'here', "don't", 'of', 'com', "couldn't", "hadn't", 'doing', 'each', "didn't", 'so', 'these', 'after', "wasn't", "we'd", 'be', 'herself', 'she', 'only', 'however', 'once', 'where', "here's", 'into', "doesn't", 'which', "aren't", "he'd", 'i', 'her', 'who', 'itself', "they'll", 'if', 'more', 'further', 'like', 'on', 'our', "hasn't", 'at', "we'll", 'with', "he's", 'all', 'k', 'both', 'himself', 'that', 'during', "you'll", "you're", 'since', 'has', 'would', 'before', 'because', 'its', "she's", 'this', 'those', 'http', 'under', "let's", 'theirs', "who's", 'there', 'themselves', 'else', 'such', 'am', 'again', "mustn't", 'yourselves', 'some', 'do', 'him', 'ever', 'been', 'an', 'other', "they've", 'own', 'down', 'above', 'a', 'below', 'whom', "how's", 'shall', "you'd", "she'd", 'your', 'up', 'my', 'too', 'his', 'he', "wouldn't", 'about', "i'll", "shan't", 'hers', 'them', "they're", 'fe
# ...

# %%
#分析高頻率單字#分析Ruby的文本

import nltk
from wordcloud import STOPWORDS

dataset = wordlists.raw('Argument First Draft_Ruby.txt')

tokens = dataset.split(' ')
clean_tokens = tokens[:]

for token in tokens:
  if token.lower() in STOPWORDS:
    clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)

# for key,val in freq.items():
#  print (str(key) + ':' + str(val))
freq.plot(20,cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
#分析高頻率單字#分析Zozo的文本

import nltk
from wordcloud import STOPWORDS

dataset = wordlists.raw('Argument Essay outline _ first draft _ We should wash our clothes less often_Zozo.txt')

tokens = dataset.split(' ')
clean_tokens = tokens[:]

for token in tokens:
  if token.lower() in STOPWORDS:
    clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)

# for key,val in freq.items():
#  print (str(key) + ':' + str(val))
freq.plot(20,cumulative=False)
# Out:
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
import nltk
from nltk.tokenize import word_tokenize
#Part of speech tagging (POS)詞性標記
text = "Argument Essay outline _ first draft _ We should wash our clothes less often_Zozo.txt"
#Tokenize the text
tex = word_tokenize(text)
nltk.pos_tag(tex)
# Out:
# [('Argument', 'NNP'),
#  ('Essay', 'NNP'),
#  ('outline', 'NN'),
#  ('_', 'NNP'),
#  ('first', 'RB'),
#  ('draft', 'VBZ'),
#  ('_', 'NN'),
#  ('We', 'PRP'),
#  ('should', 'MD'),
#  ('wash', 'VB'),
#  ('our', 'PRP$'),
#  ('clothes', 'NNS'),
#  ('less', 'RBR'),
#  ('often_Zozo.txt', 'RB')]
